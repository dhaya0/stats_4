# %% [markdown]
# <a href="https://colab.research.google.com/github/dhaya0/stats_4/blob/main/class1_jan_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
print("hello")
# Out:
# hello

# %%
a = 5
b = 10
c = a + b
c
# Out:
# 15

# %%
ad_expense = [20, 50, 80, 100]
sales = [50, 70, 90, 120]
plt.plot (ad_expense, sales)
# plotting code
